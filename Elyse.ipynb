# %%
from classes import *
from functions import *
import pandas as pd

# %%
raw_mentordata = pd.read_csv("Data/test3/mentor.csv")
raw_menteedata = pd.read_csv("Data/test3/mentee.csv")
raw_mentordata.head()
# Out:
#            Timestamp    First      Last  Phone number           Email Address  \
# 0  5/6/2020 15:30:37    Elyse   Garreau    6508899836   egarreau@berkeley.edu
# 1  5/6/2020 15:32:31    Alice  Beaumont    1234567899         alice@gmail.com
# 2  5/6/2020 19:36:49    Allen        Li    8058321156  allenli75@berkeley.edu
# 3  5/6/2020 22:11:12  Jasmine       Ang  234-964-1247    testing123@gmail.com
# 4  5/7/2020 10:12:00    Kenny        1a    5101111111             a@gmail.com
#
#   When you were an undergraduate student, what major or course of study did you pursue?  \
# 0                                   Computer Science
# 1        Electrical Engineering and Computer Science
# 2                             Electrical Engineering
# 3                                   Computer Science
# 4                                   Computer Science
#
#   If you pursued a second major, please indicate which one below.   \
# 0                                       Data Science
# 1                                           Business
# 2                                   Computer Science
# 3                                  Cognitive Science
# 4                       I did not attend university.
#
#   What is your current (or most recent) primary occupation?  \
# 0                                            Student
# 1                                                CTO
# 2                                    Product Manager
# 3                                 Software Developer
# 4                                            Student
#
#       What are your professional interests/passions?  \
# 0  Data Science, Machine Learning, Distributed Sy...
# 1         Blockchain, Computer Science, Data Science
# 2  Computer Science, Data Science, Software Engin...
# 3  Blockchain, Computer Science, Data Science, So...
# 4                                   Computer Science
#
#             What are some of your hobbies/interests?  ...  \
# 0                                 Art, Sports, Music  ...
# 1                                     Music, Reading  ...
# 2  Art, Sports, Music, Dance, Volunteering, Cooki...  ...
# 3  Sports, Music, Volunteering, Outdoor Activitie...  ...
# 4                        Sports, Music, Video gaming  ...
#
#   What is your experience with blockchain? [Community]  \
# 0             Experience from past projects/academia
# 1                                    Very unfamiliar
# 2             Experience from past projects/academia
# 3             Experience from past projects/academia
# 4             Experience from past projects/academia
#
#   What is your experience with blockchain? [Trading]  \
# 0                                  Somewhat familiar
# 1                                    Very unfamiliar
# 2                                  Somewhat familiar
# 3             Experience from past projects/academia
# 4                   Familiar with amateur experience
#
#   What is your experience with blockchain? [Legal]  \
# 0                 Familiar with amateur experience
# 1                                  Very unfamiliar
# 2                                Somewhat familiar
# 3                 Familiar with amateur experience
# 4                 Familiar with amateur experience
#
#    What is your experience with blockchain? [Marketing]  \
# 0             Experience from past projects/academia
# 1                                    Very unfamiliar
# 2          Professional or industry-level experience
# 3             Experience from past projects/academia
# 4             Experience from past projects/academia
#
#   What is your experience with blockchain? [Entrepreneurship]  \
# 0                                  Somewhat familiar
# 1                                    Very unfamiliar
# 2             Experience from past projects/academia
# 3             Experience from past projects/academia
# 4             Experience from past projects/academia
#
#   Would you prefer that your mentee has experience or familiarity with the fields listed above?   \
# 0                                         Experience
# 1                                      No preference
# 2               Familiarity or demonstrated interest
# 3                                      No preference
# 4                                      No preference
#
#   What are your main goals for this mentorship program?  \
# 0                                                NaN
# 1                                           Teaching
# 2                                                NaN
# 3  Would like to provide mentorship just like I r...
# 4                                                NaN
#
#                Why are you interested in blockchain?  \
# 0                                                NaN
# 1                      It is very interesting to me.
# 2                                                NaN
# 3  It is something I think more people should kno...
# 4                                                NaN
#
#            Why do you think blockchain is important?  \
# 0                                                NaN
# 1                         Flexibility of application
# 2                                                NaN
# 3  It's going to grow in its importance in the fu...
# 4                                                NaN
#
#   If your profession wasn't listed above, what is your current or most recent occupation?
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 38 columns]

# %%
mentorsdf = output_dataframe("Data/test3/mentor.csv", mentor_columns).sample(20)
mentorsdf.head()
# Out:
#       first    last             phone             email  \
# 23     Tony   Stark    (567) 349-3555      ts@gmail.com
# 22  Michael   Scott        1234567899   mc@facebook.com
# 4     Kenny      1a        5101111111       a@gmail.com
# 14      Bob    Ross        1234568012     bob@gmail.com
# 41     Todd  Chavez  (650) 955 - 2355  aquark@yahoo.com
#
#                      major                  second_major                job  \
# 23  Mechanical Engineering                           NaN        Founder/CEO
# 22        Computer Science                           NaN  Software Engineer
# 4         Computer Science  I did not attend university.            Student
# 14            Data Science                           NaN  Software Engineer
# 41               Economics                  Data Science         Researcher
#
#                                        prof_interests  \
# 23  Software Engineering/Development, Machine Lear...
# 22  Computer Science, Data Science, Cryptography, ...
# 4                                    Computer Science
# 14  Blockchain, Data Science, Web Development, Dis...
# 41  Artificial Intelligence, Product Management, U...
#
#                                               hobbies                  meet  \
# 23  Volunteering, Cooking, Running/Cross country, ...           Once a week
# 22                                 Art, Sports, Dance           Once a week
# 4                         Sports, Music, Video gaming  Once every 2-3 weeks
# 14                            Sports, Music, Politics  Once every 2-3 weeks
# 41                    Sports, Music, Baking, Politics           Once a week
#
#     ...  community trading  legal marketing  entrepreneurship  \
# 23  ...          2       4      2         2                 4
# 22  ...          0       2      4         1                 0
# 4   ...          3       2      2         3                 3
# 14  ...          2       0      0         2                 0
# 41  ...          0       2      1         0                 4
#
#                                   skills  goals  why_blockchain  \
# 23                     Somewhat familiar  Goals       Interests
# 22      Familiar with amateur experience  Goals      Interested
# 4                          No preference    NaN             NaN
# 14  Familiarity or demonstrated interest    NaN             NaN
# 41                            Experience  Goals      Interested
#
#     blockchain_importance  unlisted_profession
# 23                  Think                  NaN
# 22                  Think                  NaN
# 4                     NaN                  NaN
# 14                    NaN                  NaN
# 41             Importance                  NaN
#
# [5 rows x 37 columns]

# %%
menteesdf = output_dataframe("Data/test3/mentee.csv", mentee_columns, 1).sample(20)
menteesdf.head()
# Out:
#        first       last         phone              email              major  \
# 22    Edward     Cullen  444-444-2222     ec@arizona.net         Statistics
# 3      Kenny        Sky    5101111111       1b@gmail.com   Computer Science
# 25    Divya      Parimi  444-444-1111       dp@gmail.com   Computer Science
# 28  Channing     Durant  554-444-4444  cdurant@gmail.com  Political Science
# 47    Julius  Thompson   650-333-3331     jshu@gmail.com       Data Science
#
#                                                  job  \
# 22                                 Writer/Journalist
# 3                                  Software Engineer
# 25                Researcher, Writer/Journalist, COO
# 28  Lawyer, Consultant, Blockchain Evangelist, Miner
# 47          Lawyer, Consultant, Miner, Ph. D Student
#
#                                        prof_interests  \
# 22  Data Analytics, Cryptography, Artificial Intel...
# 3                 Blockchain, Marketing, Cryptography
# 25               Product Management, Business/Finance
# 28  Web Development, Mobile Development, UI/UX Design
# 47                      Web Development, UI/UX Design
#
#                                               hobbies                  meet  \
# 22                                    Cooking, Baking           Once a week
# 3                         Sports, Music, Video gaming  Once every 2-3 weeks
# 25                    Reading, Volunteering, Climbing           Once a week
# 28                Cooking, Baking, Outdoor Activities           Once a week
# 47  Sports, Dance, Watching TV, Politics, Running/...  Once every 2-3 weeks
#
#     utc  ... community  trading legal  marketing  entrepreneurship  \
# 22 -7.0  ...         2        1     1          2                 1
# 3   8.0  ...         1        1     0          1                 0
# 25 -8.0  ...         4        4     1          1                 1
# 28 -5.0  ...         2        2     3          2                 2
# 47 -5.0  ...         4        4     1          4                 4
#
#                                            skills  goals  why_blockchain  \
# 22       Privacy, Usability, Scalability, Trading     12              44
# 3                     Marketing, Entrepreneurship    NaN             NaN
# 25                    Governance, Design, Product    NaN             NaN
# 28  Usability, Research, Design, Legal, Marketing    NaN             NaN
# 47            Privacy, Research, Community, Legal    NaN             NaN
#
#     blockchain_importance      second_major
# 22                      4               NaN
# 3                     NaN               NaN
# 25                    NaN         Economics
# 28                    NaN  Pure Mathematics
# 47                    NaN               NaN
#
# [5 rows x 36 columns]

# %%
mentors = output_mentors(mentorsdf)
mentees = output_mentees(menteesdf)

# %%
matchScore(mentees, mentors)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-b4a5814e15fe> in <module>
# ----> 1 matchScore(mentees, mentors)
#
# ~/Desktop/for now/she256/ursatechmentorshipmatching/functions.py in matchScore(menteeList, mentorList)
#      70                 score += pow(2, (menteeTime - mentorTime)) * 6
#      71
# ---> 72             score += mentee_skills(mentee, mentor)
#      73
#      74             mentee.scores[mentor_id] = score
#
# ~/Desktop/for now/she256/ursatechmentorshipmatching/functions.py in mentee_skills(mentee, mentor)
#     169         score += mentor.research
#     170     if "Design" in mentee.skills:
# --> 171         score += mentor.design
#     172     if "Development" in mentee.skills:
#     173         score += mentor.development
#
# TypeError: unsupported operand type(s) for +=: 'int' and 'str'

# %%
mentees[2].scores
# Out:
# {-1: 14.0030517578125,
#  -2: 38.62538146972656,
#  -3: 68.88235294117646,
#  -4: 38.310891544117645,
#  -5: 18.838235294117645,
#  -6: 53.29449911678539,
#  -7: 14.29488058651195,
#  -8: 21.463834764831844,
#  -9: 25.919213014490463,
#  -10: 27.294499116785385,
#  -11: 15.5,
#  -12: 54.54449911678539,
#  -13: 28.0030517578125,
#  -14: 15.25152587890625,
#  -15: 4.006103515625,
#  -16: 27.294499116785385,
#  -17: 13.297169404871324,
#  -18: 14.25152587890625,
#  -19: 23.91949911678539,
#  -20: 14.250762939453125}

# %%
preferencelists(mentees, mentors)
mentees[3].preferences
# Out:
# [-2,
#  -19,
#  -20,
#  -16,
#  -5,
#  -18,
#  -12,
#  -6,
#  -17,
#  -7,
#  -10,
#  -14,
#  -1,
#  -9,
#  -13,
#  -8,
#  -3,
#  -11,
#  -4,
#  -15]

# %%
proposals = stableMarriage(mentees, mentors)
proposals

# %%
output_final(proposals, mentors, mentees)
